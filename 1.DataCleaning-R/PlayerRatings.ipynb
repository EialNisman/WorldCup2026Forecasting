# %% [markdown]
# # Player Data Kaggle-Fjelstul
#
# ## Objectives
#
# Develop a dataset with Kaggle dataset ID's, Fjestul Dataset IDs, and Player Names.
#
# Thgis will serve as a mathcing tool to assign season data (from the kaggle dataset) to world cup data (from thje Fjestul dataset)
#
#
# ## Acknowledgments
#
# Data in this notebook is taken from Kaggle using Kaggle's API. The dataset in Kaggle is made from data originally from Transfermarket.com.
#
# ## Libraries

# %%
library(dplyr)
library(here)
library(stringr)
library(stringi)

# %% [markdown]
# ## Player data (Kaggle)
#
# ### Call Data with our Kaggle API

# %%
system("kaggle datasets download davidcariboo/player-scores -p kaggle_data")

unzip("kaggle_data/player-scores.zip",exdir = "kaggle_data")

# %%
player_data <- read.csv(here("1.DataCleaning-R", "kaggle_data", "players.csv"), stringsAsFactors = FALSE, encoding = "UTF-8")

colnames(player_data)
# Out:
#  [1] "player_id"
#  [2] "first_name"
#  [3] "last_name"
#  [4] "name"
#  [5] "last_season"
#  [6] "current_club_id"
#  [7] "player_code"
#  [8] "country_of_birth"
#  [9] "city_of_birth"
# [10] "country_of_citizenship"
# [11] "date_of_birth"
# [12] "sub_position"
# [13] "position"
# [14] "foot"
# [15] "height_in_cm"
# [16] "contract_expiration_date"
# [17] "agent_name"
# [18] "image_url"
# [19] "international_caps"
# [20] "international_goals"
# [21] "current_national_team_id"
# [22] "url"
# [23] "current_club_domestic_competition_id"
# [24] "current_club_name"
# [25] "market_value_in_eur"
# [26] "highest_market_value_in_eur"

# %%
player_names <- player_data %>%
    select(player_id, name)

# %% [markdown]
# ## Clean Data
#
# ### Lets get the player names and IDs from Fjestul

# %%
worldcup_players <- readRDS(here("1.DataCleaning-R", "Data", "RDS", "FullRoster.rds"))

worldcup_players <- worldcup_players %>%
    select(player_id, full_name) %>%
        distinct(player_id, .keep_all = TRUE)

# %% [markdown]
# Since the dataset for worldcup_players and player_namess come from sepearate orders their player_id system is different. It is also likely that some names may not match exaclty, lets investigate this possibility.

# %%
length(setdiff(worldcup_players$full_name, player_names$name))
length(worldcup_players$full_name)
setdiff(worldcup_players$full_name, player_names$name)
# Out:
# [1] 856
# [1] 2379
#   [1] "Loun<U+00E8>s Gaouaoui"     "Madjid Bougherra"
#   [3] "Nadir Belhadj"              "Antar Yahia"
#   [5] "Yazid Mansouri"             "Rafik Sa<U+00EF>fi"
#   [7] "Habib Bella<U+00EF>d"       "Abdelkader La<U+00EF>faoui"
#   [9] "Karim Ziani"                "Faouzi Chaouchi"
#  [11] "Adl<U+00E8>ne Guedioura"    "Diego Pozo"
#  [13] "Clemente Rodr<U+00ED>guez"  "Mario Bolatti"
#  [15] "Gabriel Heinze"             "Juan Sebasti<U+00E1>n Ver<U+00F3>n"
#  [17] "Ariel Garc<U+00E9>"         "Mart<U+00ED>n Palermo"
#  [19] "Maxi Rodr<U+00ED>guez"      "Lucas Neill"
#  [21] "Tim Cahill"                 "Jason Culina"
#  [23] "Michael Beauchamp"          "Brett Emerton"
#  [25] "Joshua Kennedy"             "Harry Kewell"
#  [27] "Scott Chipperfield"         "Vince Grella"
#  [29] "Eugene Galekovic"           "Richard Garcia"
#  [31] "David Carney"               "Dario Vido<U+0161>i<U+0107>"
#  [33] "Mark Bresciano"             "not applicable Maicon"
#  [35] "not applicable L<U+00FA>cio" "not applicable Juan"
#  [37] "not applicable Elano"       "Gilberto Silva"
#  [39] "Lu<U+00ED>s Fabiano"        "not applicable Kak<U+00E1>"
#  [41] "not applicable Robinho"     "not applicable Luis<U+00E3>o"
#  [43] "not applicable Gilberto"    "not applicable Josu<U+00E9>"
#  [45] "not applicable Ramires"     "not applicable Kl<U+00E9>berson"
#  [47] "not applicable Nilmar"      "not applicable Doni"
#  [49] "not applicable Grafite"     "Nicolas Nkoulou"
#  [51] "Rigobert Song"              "not applicable Geremi"
#  [53] "Achille Eman<U+00E1>"       "Eric Maxim Choupo-Moting"
#  [55] "Souleymanou Hamidou"        "Mohammadou Idrissou"
#  [57] "Jo<U+00EB>l Matip"          "Guy N'dy Assemb<U+00E9>"
#  [59] "Ismael Fuentes"             "Waldo Ponce"
#  [61] "Humberto Suazo"             "Jorge Valdivia"
#  [63] "Miguel Pinto"               "Gonzalo Fierro"
#  [65] "Rodrigo Millar"             "Esteban Paredes"
#  [67] "Luis Mar<U+00ED>n"          "Thomas S<U+00F8>rensen"
#  [69] "Jesper Gr<U+00F8>nkj<U+00E6>r" "Jon Dahl Tomasson"
#  [71] "Martin J<U+00F8>rgensen"    "Per Kr<U+00F8>ldrup"
#  [73] "S<U+00F8>ren Larsen"        "David James"
#  [75] "Robert Green"               "Stephen Warnock"
#  [77] "Ledley King"                "Emile Heskey"
#  [79] "Eric Abidal"                "Thierry Henry"
#  [81] "Arne Friedrich"             "not applicable Cacau"
#  [83] "Hans-J<U+00F6>rg Butt"      "Daniel Agyei"
#  [85] "Hans Sarpei"                "John Paintsil"
#  [87] "Stephen Appiah"             "Prince Tagoe"
#  [89] "Isaac Vorsah"               "Stephen Ahorlu"
#  [91] "Lee Addy"                   "Richard Kingson"
#  [93] "Kostas Chalkias"            "Giourkas Seitaridis"
#  [95] "Nikos Spyropoulos"          "Angelos Charisteas"
#  [97] "Giorgos Karagounis"         "Dimitris Salpingidis"
#  [99] "Vasilis Torosidis"          "Sotirios Kyrgiakos"
# [101] "Kostas Katsouranis"         "Sakis Prittas"
# [103] "Ricardo Canales"            "Osman Ch<U+00E1>vez"
# [105] "Johnny Palacios"            "V<U+00ED>ctor Bern<U+00E1>rdez"
# [107] "Hendry Thomas"              "Ram<U+00F3>n N<U+00FA><U+00F1>ez"
# [109] "Carlos Pav<U+00F3>n"        "Jerry Palacios"
# [111] "David Suazo"                "Georgie Welcome"
# [113] "Roger Espinoza"             "Boniek Garc<U+00ED>a"
# [115] "Walter Mart<U+00ED>nez"     "Mauricio Sabill<U+00F3>n"
# [117] "<U+00C9>dgar <U+00C1>lvarez" "Noel Valladares"
# [119] "Danilo Turcios"             "Amado Guevara"
# [121] "Donis Escober"              "Sergio Mendoza"
# [123] "Fabio Cannavaro"            "Gennaro Gattuso"
# [853] "Ronald Ara<U+00FA>jo"       "Sebasti<U+00E1>n Sosa"
# [855] "Joe Morrell"                "Jonny Williams"

# %% [markdown]
# We can see a very significant amount of players have mismatched names.

# %%
set.seed(12)

player_names %>%
    slice_sample(n = 20) %>%
        select(name)
# Out:
#    name
# 1  Brad Halliday
# 2  Pedro Botelho
# 3  Gabriel Palmero
# 4  Martin Jiranek
# 5  You-hyeon Lee
# 6  Islam Issa
# 7  Andu Kelati
# 8  Riccardo Brosco
# 9  Mohammed Abera
# 10 Claude Gon<U+00E7>alves
# 11 Tayfur Bing<U+00F6>l
# 12 Jer<U+00F3>nimo D<U+00F3>mina
# 13 Hampus N<U+00E4>sstr<U+00F6>m
# 14 Muhammed Ergin
# 15 Bj<U+00F6>rn Engels
# 16 Dusan Cvetinovic
# 17 Paulo Monteiro
# 18 Fraser Murray
# 19 Tom Dele-Bashiru
# 20 Manuel Ravasio

# %% [markdown]
# After manually inspecting I see some players are just spelled slightly differently in one dataset vs the other. For example Antar/Anthar Yahiya. Let's trouble shoot other issues first since this might require a lot of manual comparison which will be easier to do with less observations.

# %%
player_names %>%
  filter(grepl("Anthar Yahia", name)) %>%
    select(name)

worldcup_players %>%
  filter(grepl("Antar Yahia", full_name)) %>%
    select(full_name)
# Out:
#   name
# 1 Anthar Yahia
#   full_name
# 1 Antar Yahia

# %% [markdown]
# Some of the player names also differ in the datasets because of accents. For example Ronald Araujo.

# %%
player_names %>%
  filter(grepl("Ronald Araujo", name)) %>%
    select(name)

worldcup_players %>%
  filter(grepl("Ronald Ara", full_name)) %>%
    select(full_name)
# Out:
#   name
# 1 Ronald Araujo
#   full_name
# 1 Ronald Ara<U+00FA>jo

# %% [markdown]
# The accents seem to be a relevant issue across a lot of players. Let's write a function to normalize all text by removing accents. Also making sure to decode all text in the process.

# %%
# This was done with significant help from Codex AI
decode_unicode_tags <- function(x) {
  fix_one <- function(s) {
    matches <- regmatches(
      s,
      gregexpr("<U\\+[0-9A-Fa-f]{4,6}>", s, perl = TRUE)
    )[[1]]

    if (length(matches) == 1 && matches[1] == "") return(s)

    for (m in matches) {
      hex <- sub("<U\\+([0-9A-Fa-f]{4,6})>", "\\1", m, perl = TRUE)
      replacement <- intToUtf8(strtoi(hex, base = 16))
      s <- sub(m, replacement, s, fixed = TRUE)
    }

    s
  }

  vapply(x, fix_one, character(1))
}

remove_accents <- function(x) {
  x <- decode_unicode_tags(x)
  x <- enc2utf8(x)
  stringi::stri_trans_general(x, "Latin-ASCII")
}

#Test
remove_accents("Ronald Araújo")
remove_accents("Ángel Di María")
remove_accents("Cristiano Ronaldo")
# Out:
# [1] "Ronald Araujo"
# [1] "Angel Di Maria"
# [1] "Cristiano Ronaldo"

# %% [markdown]
# Seems to work pretty well, lets apply it to both of our datasets and then compare again

# %%
player_names <- player_names %>%
    mutate(name = remove_accents(name))

worldcup_players <- worldcup_players %>%
    mutate(full_name = remove_accents(full_name))

length(setdiff(worldcup_players$full_name, player_names$name))
length(worldcup_players$full_name)
setdiff(worldcup_players$full_name, player_names$name)
# [663] "Kim Jin-su"                 "Kim Min-jae"
# [665] "Hwang In-beom"              "Paik Seung-ho"
# [667] "Cho Gue-sung"               "Song Bum-keun"
# [669] "Son Jun-ho"                 "Kim Moon-hwan"
# [671] "Hwang Ui-jo"                "Na Sang-ho"
# [673] "Lee Kang-in"                "Kwon Kyung-won"
# [675] "Kwon Chang-hoon"            "Kim Tae-hwan"
# [677] "Cho Yu-min"                 "Jeong Woo-yeong"
# [679] "Song Min-kyu"               "not applicable Gavi"
# [681] "not applicable Rodri"       "not applicable Pedri"
# [683] "Bilel Ifa"                  "Hannibal Mejbri"
# [685] "Taha Yassine Khenissi"      "Mohamed Ali Ben Romdhane"
# [687] "Seifeddine Jaziri"          "Anis Ben Slimane"
# [689] "Sebastian Sosa"             "Joe Morrell"
# [691] "Jonny Williams"

# %% [markdown]
# Our set difference went down 165 observations! Lets keep trouble shooting.
#
# There seems to be a few players with "not applicable" as their first name. Let's explore this issue.

# %%
worldcup_players %>%
    filter(grepl("not applicable", full_name)) %>%
        print(n=5)

worldcup_players %>%
    filter(grepl("not applicable", full_name)) %>%
        distinct(full_name) %>%
            nrow()
# Out:
# # A tibble: 88 x 2
#   player_id full_name
#   <chr>     <chr>
# 1 P-94551   not applicable Maicon
# 2 P-42918   not applicable Lucio
# 3 P-98607   not applicable Juan
# 4 P-78264   not applicable Elano
# 5 P-58388   not applicable Kaka
# # i 83 more rows
# [1] 85

# %%
readRDS(here("1.DataCleaning-R", "Data", "RDS", "FullRoster.rds")) %>%
    filter(given_name== "not applicable") %>%
        print(n=10)
# Out:
# # A tibble: 113 x 9
#    tournament_id team_name team_id team_code player_id family_name   given_name
#    <chr>         <chr>     <chr>   <chr>     <chr>     <chr>         <chr>
#  1 WC-2010       Brazil    T-09    BRA       P-94551   "Maicon"      not applic~
#  2 WC-2010       Brazil    T-09    BRA       P-42918   "L\u00facio"  not applic~
#  3 WC-2010       Brazil    T-09    BRA       P-98607   "Juan"        not applic~
#  4 WC-2010       Brazil    T-09    BRA       P-78264   "Elano"       not applic~
#  5 WC-2010       Brazil    T-09    BRA       P-58388   "Kak\u00e1"   not applic~
#  6 WC-2010       Brazil    T-09    BRA       P-13354   "Robinho"     not applic~
#  7 WC-2010       Brazil    T-09    BRA       P-32968   "Luis\u00e3o" not applic~
#  8 WC-2010       Brazil    T-09    BRA       P-30363   "Gilberto"    not applic~
#  9 WC-2010       Brazil    T-09    BRA       P-74066   "Josu\u00e9"  not applic~
# 10 WC-2010       Brazil    T-09    BRA       P-86499   "Ramires"     not applic~
# # i 103 more rows
# # i 2 more variables: position_code <chr>, full_name <chr>

# %%
#Let's check some of these players on the Kaggle dataset
set.seed(123)

player_names %>% 
    select(name) %>%
        filter(grepl("Maicon|Elano|Rodri", name)) %>%
            slice_sample(n=10)
# Out:
#    name
# 1  Ramiro Ruiz Rodriguez
# 2  Rodrigo Melro
# 3  Fer Rodriguez
# 4  Jay Rodriguez
# 5  Rodrigo Caseres
# 6  Rodrigo Varanda
# 7  Diego Rodriguez
# 8  Rodrigo Alirio
# 9  Rodrigo
# 10 Javi Rodriguez

# %% [markdown]
# Some of the players seem to be only reffered to by one name in both datasets. Lets take out the not applicable and see improvements.

# %%
remove_not_applicable <- function(x) {
  gsub("not applicable\\s+", "", x)
}

worldcup_players <- worldcup_players %>%
  mutate(full_name = remove_not_applicable(full_name))

length(setdiff(worldcup_players$full_name, player_names$name))
length(worldcup_players$full_name)
setdiff(worldcup_players$full_name, player_names$name)
# Out:
# [1] 617
# [1] 2379
#   [1] "Lounes Gaouaoui"            "Madjid Bougherra"
#   [3] "Nadir Belhadj"              "Antar Yahia"
#   [5] "Yazid Mansouri"             "Rafik Saifi"
#   [7] "Habib Bellaid"              "Abdelkader Laifaoui"
#   [9] "Karim Ziani"                "Faouzi Chaouchi"
#  [11] "Diego Pozo"                 "Clemente Rodriguez"
#  [13] "Mario Bolatti"              "Gabriel Heinze"
#  [15] "Juan Sebastian Veron"       "Ariel Garce"
#  [17] "Martin Palermo"             "Maxi Rodriguez"
#  [19] "Lucas Neill"                "Tim Cahill"
#  [21] "Jason Culina"               "Michael Beauchamp"
#  [23] "Brett Emerton"              "Joshua Kennedy"
#  [25] "Harry Kewell"               "Scott Chipperfield"
#  [27] "Vince Grella"               "Eugene Galekovic"
#  [29] "Richard Garcia"             "David Carney"
#  [31] "Dario Vidosic"              "Mark Bresciano"
#  [33] "Elano"                      "Gilberto Silva"
#  [35] "Luis Fabiano"               "Kleberson"
#  [37] "Nilmar"                     "Doni"
#  [39] "Grafite"                    "Nicolas Nkoulou"
#  [41] "Rigobert Song"              "Geremi"
#  [43] "Achille Emana"              "Eric Maxim Choupo-Moting"
#  [45] "Souleymanou Hamidou"        "Mohammadou Idrissou"
#  [47] "Guy N'dy Assembe"           "Ismael Fuentes"
#  [49] "Waldo Ponce"                "Humberto Suazo"
#  [51] "Jorge Valdivia"             "Miguel Pinto"
#  [53] "Gonzalo Fierro"             "Rodrigo Millar"
#  [55] "Esteban Paredes"            "Luis Marin"
#  [57] "Jesper Gronkjaer"           "Jon Dahl Tomasson"
#  [59] "David James"                "Robert Green"
#  [61] "Stephen Warnock"            "Ledley King"
#  [63] "Emile Heskey"               "Thierry Henry"
#  [65] "Arne Friedrich"             "Hans-Jorg Butt"
#  [67] "Daniel Agyei"               "Hans Sarpei"
#  [69] "John Paintsil"              "Stephen Appiah"
#  [71] "Prince Tagoe"               "Isaac Vorsah"
#  [73] "Stephen Ahorlu"             "Lee Addy"
#  [75] "Richard Kingson"            "Kostas Chalkias"
#  [77] "Giourkas Seitaridis"        "Nikos Spyropoulos"
#  [79] "Angelos Charisteas"         "Giorgos Karagounis"
#  [81] "Dimitris Salpingidis"       "Vasilis Torosidis"
#  [83] "Sotirios Kyrgiakos"         "Kostas Katsouranis"
#  [85] "Sakis Prittas"              "Ricardo Canales"
#  [87] "Osman Chavez"               "Johnny Palacios"
#  [89] "Victor Bernardez"           "Hendry Thomas"
#  [91] "Ramon Nunez"                "Carlos Pavon"
#  [93] "Jerry Palacios"             "David Suazo"
# [537] "Jerome Ngom Mbekeli"        "Moumi Ngamaleu"
# [539] "Georges-Kevin Nkoudou"      "Andre-Frank Zambo Anguissa"
# [541] "Samuel Gouet"               "Nouhou Tolo"
# [543] "Souaibou Marou"             "Liam Fraser"
# [545] "Lucas Cavallini"            "Daniel Chacon"
# [547] "Keysher Fuller"             "Gerson Torres"
# [549] "Douglas Lopez"              "William Pacho"
# [551] "Romario Ibarra"             "Michael Estrada"
# [553] "Xavier Arreaga"             "Sebas Mendez"
# [555] "Djorkaeff Reasco"           "Lawrence Ati-Zigi"
# [557] "Abdul Fatawu Issahaku"      "Ibrahim Danlad"
# [559] "Abdul Manaf Nurudeen"       "Baba Rahman"
# [561] "Shojae Khalilzadeh"         "Hossein Kanaanizadegan"
# [563] "Ahmad Nourollahi"           "Hossein Hosseini"
# [565] "Abolfazl Jalali"            "Ilias Chair"
# [567] "Bilal El Khannous"          "Badr Benoun"
# [569] "Yahya Jabrane"              "Saad Al-Sheeb"
# [571] "Ro-Ro"                      "Abdulaziz Hatem"
# [573] "Ali Assadalla"              "Hassan Al-Haydos"
# [575] "Musab Kheder"               "Homam Ahmed"
# [577] "Ismaeel Mohammad"           "Khalid Muneer"
# [579] "Salem Al-Hajri"             "Yousef Hassan"
# [581] "Naif Al-Hadhrami"           "Mostafa Meshaal"
# [583] "Mohammed Al-Rubaie"         "Abdulellah Al-Malki"
# [585] "Hassan Al-Tambakti"         "Abdulrahman Al-Aboud"
# [587] "Moussa N'Diaye"             "Moustapha Name"
# [589] "Srdan Babic"                "Filip Duricic"
# [591] "Yoon Jong-gyu"              "Kim Jin-su"
# [593] "Kim Min-jae"                "Hwang In-beom"
# [595] "Paik Seung-ho"              "Cho Gue-sung"
# [597] "Song Bum-keun"              "Son Jun-ho"
# [599] "Kim Moon-hwan"              "Hwang Ui-jo"
# [601] "Na Sang-ho"                 "Lee Kang-in"
# [603] "Kwon Kyung-won"             "Kwon Chang-hoon"
# [605] "Kim Tae-hwan"               "Cho Yu-min"
# [607] "Jeong Woo-yeong"            "Song Min-kyu"
# [609] "Bilel Ifa"                  "Hannibal Mejbri"
# [611] "Taha Yassine Khenissi"      "Mohamed Ali Ben Romdhane"
# [613] "Seifeddine Jaziri"          "Anis Ben Slimane"
# [615] "Sebastian Sosa"             "Joe Morrell"
# [617] "Jonny Williams"

# %% [markdown]
# Great! 74 out of the 85 players with not applicable were solved with this issue. Lets asses the other 11. We can do this by checking all full names with no spaces in the sett differences list. If we have 11 then we know we got all of the not applicables we're missing.

# %%
unmatched_players <- setdiff(worldcup_players$full_name, player_names$name)

one_word_unmatched <- unmatched_players[!grepl("\\s", unmatched_players)]

length(one_word_unmatched)
one_word_unmatched
# Out:
# [1] 11
#  [1] "Elano"     "Kleberson" "Nilmar"    "Doni"      "Grafite"   "Geremi"
#  [7] "Yakubu"    "Miguel"    "Deco"      "Cedric"    "Ro-Ro"

# %%
player_data_clean <- player_data %>%
  mutate(clean_name = remove_not_applicable(remove_accents(name)))

pattern <- paste0("\\b(", paste(one_word_unmatched, collapse = "|"), ")\\b")

player_data_clean %>%
  filter(grepl(pattern, clean_name)) %>%
    filter(!(clean_name %in% worldcup_players$full_name)) %>%
      distinct(name, clean_name, last_season, international_caps) %>%
        filter(last_season>= 2010 & international_caps > 0)
# Out:
#    name                         clean_name            last_season
# 1  Miguel Lopes                 Miguel Lopes          2024
# 2  Miguel Lloyd                 Miguel Lloyd          2025
# 3  Luis Miguel Rodr<U+00ED>guez Luis Miguel Rodriguez 2024
# 4  C<U+00E9>dric Soares         Cedric Soares         2025
# 5  C<U+00E9>dric Bakambu        Cedric Bakambu        2025
# 6  C<U+00E9>dric Hountondji     Cedric Hountondji     2024
# 7  Cedric Teuchert              Cedric Teuchert       2025
# 8  Pedro Miguel                 Pedro Miguel          2025
# 9  Cedric Itten                 Cedric Itten          2025
# 10 Miguel Almir<U+00F3>n        Miguel Almiron        2025
# 11 Miguel Lu<U+00ED>s           Miguel Luis           2025
# 12 C<U+00E9>dric Kipr<U+00E9>   Cedric Kipre          2024
# 13 C<U+00E9>dric Zesiger        Cedric Zesiger        2025
# 14 Miguel N<U+00F3>brega        Miguel Nobrega        2025
# 15 Miguel Reisinho              Miguel Reisinho       2024
# 16 Miguel de la Fuente          Miguel de la Fuente   2024
# 17 Miguel Merentiel             Miguel Merentiel      2025
# 18 Miguel Navarro               Miguel Navarro        2025
# 19 Miguel Baeza                 Miguel Baeza          2025
# 20 Miguel Guti<U+00E9>rrez      Miguel Gutierrez      2025
# 21 Cedric Teguia                Cedric Teguia         2025
# 22 Miguel Reichmuth             Miguel Reichmuth      2025
# 23 Miguel <U+00C1>ngel Morro    Miguel Angel Morro    2024
# 24 Miguel Sandberg              Miguel Sandberg       2025
# 25 Miguel Rodr<U+00ED>guez      Miguel Rodriguez      2025
# 26 Miguel Silveira              Miguel Silveira       2024
# 27 Miguel Menino                Miguel Menino         2024
# 28 Miguel Monsalve              Miguel Monsalve       2025
# 29 Miguel G<U+00F3>mez          Miguel Gomez          2025
# 30 Miguel Ram<U+00ED>rez        Miguel Ramirez        2025
# 31 C<U+00E9>dric Nuozzi         Cedric Nuozzi         2025
# 32 Miguel Carvalho              Miguel Carvalho       2025
# 33 Miguel Chaiwa                Miguel Chaiwa         2025
# 34 Miguel Perez                 Miguel Perez          2025
# 35 Mardoch<U+00E9>e Miguel      Mardochee Miguel      2025
# 36 Miguel Di Pizio              Miguel Di Pizio       2025
# 37 Miguel <U+00C1>ngel Beltre   Miguel Angel Beltre   2025
# 38 Miguel Agamez                Miguel Agamez         2024
# 39 Miguel Marulanda             Miguel Marulanda      2025
#    international_caps
# 1   4
# 2  47
# 3   1
# 4  34
# 5  67
# 6  29
# 7   8
# 8  99
# 9  13
# 10 75
# 11  6
# 12  1
# 13  6
# 14  2
# 15  1
# 16  4
# 17  1
# 18 23
# 19  1
# 20  2
# 21  5
# 22  3
# 23  2
# 24  8
# 25  5
# 26  1
# 27  2
# 28 17
# 29  3
# 30  2
# 31  2
# 32  2
# 33 16
# 34  1
# 35  6
# 36  3
# 37  6
# 38  9
# 39  2

# %% [markdown]
# After further research Im comfortable assigning the full names to the following players.

# %%
worldcup_players <- worldcup_players %>%
  mutate(
    full_name = case_when(
      full_name == "Elano" ~ "Elano Yegen",
      full_name == "Cedric" ~ "Cedric Soares",
      full_name == "Ro-Ro" ~ "Pedro Miguel",
      TRUE ~ full_name
    )
  )

# %% [markdown]
# The other few players with one word names we will leave as undefined for now.
#
#
# I will Have CODEX AI go thorugh the full list of differences and through the full p[layers.csv dataset and find clear minimal gramatical mismatches. I willl then manually check a few to minimize likelihood of errors.

# %%
# Obvious name fixes found by comparing unmatched World Cup names to players.csv
# Only includes high-confidence spelling, punctuation, or known single-name expansions.
worldcup_players <- worldcup_players %>%
  mutate(
    full_name = case_when(
      full_name == "Abdulrahman Al-Aboud" ~ "Abdulrahman Al-Oboud",
      full_name == "Eric Maxim Choupo-Moting" ~ "Eric-Maxim Choupo-Moting",
      full_name == "Lawrence Ati-Zigi" ~ "Lawrence Ati Zigi",
      full_name == "Abdulaziz Hatem" ~ "Abdulaziz Hatim",
      full_name == "Abdulellah Al-Malki" ~ "Abdulelah Al-Malki",
      full_name == "Ahmed Hegazi" ~ "Ahmed Hegazy",
      full_name == "Aleksandr Yerokhin" ~ "Aleksandr Erokhin",
      full_name == "Aleksei Ionov" ~ "Aleksey Ionov",
      full_name == "Aleksei Kozlov" ~ "Aleksey Kozlov",
      full_name == "Aleksei Miranchuk" ~ "Aleksey Miranchuk",
      full_name == "Andrey Yeshchenko" ~ "Andrey Eshchenko",
      full_name == "Antar Yahia" ~ "Anthar Yahia",
      full_name == "Bilal El Khannous" ~ "Bilal El Khannouss",
      full_name == "Brian Idowu" ~ "Bryan Idowu",
      full_name == "Cheick Tiote" ~ "Cheik Tiote",
      full_name == "Daler Kuzyayev" ~ "Daler Kuzyaev",
      full_name == "Dimitris Salpingidis" ~ "Dimitrios Salpingidis",
      full_name == "Dmitri Kombarov" ~ "Dmitriy Kombarov",
      full_name == "Erick Davis" ~ "Eric Davis",
      full_name == "Filip Duricic" ~ "Filip Djuricic",
      full_name == "Georgi Shchennikov" ~ "Georgiy Shchennikov",
      full_name == "Giorgian De Arrascaeta" ~ "Giorgian de Arrascaeta",
      full_name == "Guy N'dy Assembe" ~ "Guy Ndy Assembe",
      full_name == "Hannes THor Halldorsson" ~ "Hannes Thor Halldorsson",
      full_name == "Hassan Al-Haydos" ~ "Hasan Al-Haydos",
      full_name == "Marco Urena" ~ "Marcos Urena",
      full_name == "Mateus Uribe" ~ "Matheus Uribe",
      full_name == "Michael Babatunde" ~ "Michel Babatunde",
      full_name == "Sergei Ignashevich" ~ "Sergey Ignashevich",
      full_name == "Sotirios Kyrgiakos" ~ "Sotiris Kyrgiakos",
      full_name == "Srdan Babic" ~ "Srdjan Babic",
      full_name == "Steve Cherundolo" ~ "Steven Cherundolo",
      full_name == "Vasili Berezutski" ~ "Vasiliy Berezutski",
      full_name == "Vasilis Torosidis" ~ "Vasilios Torosidis",
      full_name == "Viktor Fayzulin" ~ "Viktor Faizulin",
      full_name == "William Pacho" ~ "Willian Pacho",
      full_name == "Yuri Lodygin" ~ "Yuriy Lodygin",
      full_name == "Yuri Zhirkov" ~ "Yuriy Zhirkov",
      full_name == "Andrey Lunyov" ~ "Andrey Lunev",
      full_name == "Dani Carvajal" ~ "Daniel Carvajal",
      full_name == "Fyodor Kudryashov" ~ "Fedor Kudryashov",
      full_name == "Fyodor Smolov" ~ "Fedor Smolov",
      full_name == "Georges-Kevin Nkoudou" ~ "Georges-Kevin N'Koudou",
      full_name == "Giorgos Karagounis" ~ "Georgios Karagounis",
      full_name == "Giorgos Tzavellas" ~ "Georgios Tzavellas",
      full_name == "John Heitinga" ~ "Johnny Heitinga",
      full_name == "Joo-ho Park" ~ "Ju-ho Park",
      full_name == "Mbark Boussoufa" ~ "Moubarak Boussoufa",
      full_name == "Nikos Spyropoulos" ~ "Nikolaos Spyropoulos",
      full_name == "Robert Green" ~ "Rob Green",
      full_name == "Yakubu" ~ "Yakubu Aiyegbeni",
      TRUE ~ full_name
    )
  )

# %%
length(setdiff(worldcup_players$full_name, player_names$name))
length(worldcup_players$full_name)
setdiff(worldcup_players$full_name, player_names$name)
# Out:
# [1] 563
# [1] 2379
#   [1] "Lounes Gaouaoui"            "Madjid Bougherra"
#   [3] "Nadir Belhadj"              "Yazid Mansouri"
#   [5] "Rafik Saifi"                "Habib Bellaid"
#   [7] "Abdelkader Laifaoui"        "Karim Ziani"
#   [9] "Faouzi Chaouchi"            "Diego Pozo"
#  [11] "Clemente Rodriguez"         "Mario Bolatti"
#  [13] "Gabriel Heinze"             "Juan Sebastian Veron"
#  [15] "Ariel Garce"                "Martin Palermo"
#  [17] "Maxi Rodriguez"             "Lucas Neill"
#  [19] "Tim Cahill"                 "Jason Culina"
#  [21] "Michael Beauchamp"          "Brett Emerton"
#  [23] "Joshua Kennedy"             "Harry Kewell"
#  [25] "Scott Chipperfield"         "Vince Grella"
#  [27] "Eugene Galekovic"           "Richard Garcia"
#  [29] "David Carney"               "Dario Vidosic"
#  [31] "Mark Bresciano"             "Gilberto Silva"
#  [33] "Luis Fabiano"               "Kleberson"
#  [35] "Nilmar"                     "Doni"
#  [37] "Grafite"                    "Nicolas Nkoulou"
#  [39] "Rigobert Song"              "Geremi"
#  [41] "Achille Emana"              "Souleymanou Hamidou"
#  [43] "Mohammadou Idrissou"        "Ismael Fuentes"
#  [45] "Waldo Ponce"                "Humberto Suazo"
#  [47] "Jorge Valdivia"             "Miguel Pinto"
#  [49] "Gonzalo Fierro"             "Rodrigo Millar"
#  [51] "Esteban Paredes"            "Luis Marin"
#  [53] "Jesper Gronkjaer"           "Jon Dahl Tomasson"
#  [55] "David James"                "Stephen Warnock"
#  [57] "Ledley King"                "Emile Heskey"
#  [59] "Thierry Henry"              "Arne Friedrich"
#  [61] "Hans-Jorg Butt"             "Daniel Agyei"
#  [63] "Hans Sarpei"                "John Paintsil"
#  [65] "Stephen Appiah"             "Prince Tagoe"
#  [67] "Isaac Vorsah"               "Stephen Ahorlu"
#  [69] "Lee Addy"                   "Richard Kingson"
# [513] "Abdul Manaf Nurudeen"       "Baba Rahman"
# [515] "Shojae Khalilzadeh"         "Hossein Kanaanizadegan"
# [517] "Ahmad Nourollahi"           "Hossein Hosseini"
# [519] "Abolfazl Jalali"            "Ilias Chair"
# [521] "Badr Benoun"                "Yahya Jabrane"
# [523] "Saad Al-Sheeb"              "Ali Assadalla"
# [525] "Musab Kheder"               "Homam Ahmed"
# [527] "Ismaeel Mohammad"           "Khalid Muneer"
# [529] "Salem Al-Hajri"             "Yousef Hassan"
# [531] "Naif Al-Hadhrami"           "Mostafa Meshaal"
# [533] "Mohammed Al-Rubaie"         "Hassan Al-Tambakti"
# [535] "Moussa N'Diaye"             "Moustapha Name"
# [537] "Yoon Jong-gyu"              "Kim Jin-su"
# [539] "Kim Min-jae"                "Hwang In-beom"
# [541] "Paik Seung-ho"              "Cho Gue-sung"
# [543] "Song Bum-keun"              "Son Jun-ho"
# [545] "Kim Moon-hwan"              "Hwang Ui-jo"
# [547] "Na Sang-ho"                 "Lee Kang-in"
# [549] "Kwon Kyung-won"             "Kwon Chang-hoon"
# [551] "Kim Tae-hwan"               "Cho Yu-min"
# [553] "Jeong Woo-yeong"            "Song Min-kyu"
# [555] "Bilel Ifa"                  "Hannibal Mejbri"
# [557] "Taha Yassine Khenissi"      "Mohamed Ali Ben Romdhane"
# [559] "Seifeddine Jaziri"          "Anis Ben Slimane"
# [561] "Sebastian Sosa"             "Joe Morrell"
# [563] "Jonny Williams"

# %% [markdown]
# I want to assses the relevance of this unmatched players to our dataset and start considering the possibility of exc;luding some of these players.

# %%
nonmatched <- setdiff(worldcup_players$full_name, player_names$name)
fullworldcup_players <- readRDS(here("1.DataCleaning-R", "Data", "RDS", "FullRoster.rds"))

fullworldcup_players %>% 
    filter(full_name %in% nonmatched) %>%
        group_by(team_name, tournament_id) %>%
            summarize(players= sum(n())) %>%
                arrange(desc(players))
# Out:
# `summarise()` has grouped output by 'team_name'. You can override using the
# `.groups` argument.
#     team_name     tournament_id players
# 1   North Korea   WC-2010       23
# 2   New Zealand   WC-2010       18
# 3   South Korea   WC-2022       18
# 4   South Africa  WC-2010       17
# 5   Iran          WC-2014       15
# 6   South Korea   WC-2010       14
# 7   Australia     WC-2010       13
# 8   Japan         WC-2010       13
# 9   United States WC-2010       12
# 10  Honduras      WC-2010       11
# 11  Paraguay      WC-2010       11
# 12  Saudi Arabia  WC-2018       11
# 13  Mexico        WC-2010       10
# 14  Qatar         WC-2022       10
# 15  Costa Rica    WC-2014        9
# 16  Egypt         WC-2018        9
# 17  Ghana         WC-2010        9
# 18  Panama        WC-2018        9
# 19  South Korea   WC-2014        9
# 20  Australia     WC-2014        8
# 21  Chile         WC-2010        8
# 22  Tunisia       WC-2022        8
# 23  Ecuador       WC-2014        7
# 24  Ghana         WC-2014        7
# 25  Honduras      WC-2014        7
# 26  Iran          WC-2022        7
# 27  Nigeria       WC-2010        7
# 28  Switzerland   WC-2010        7
# 29  Tunisia       WC-2018        7
# 30  United States WC-2014        7
# ... ...           ...           ...
# 50  Saudi Arabia  WC-2022       4
# 51  Argentina     WC-2010       3
# 52  Australia     WC-2018       3
# 53  Costa Rica    WC-2022       3
# 54  Greece        WC-2014       3
# 55  Japan         WC-2014       3
# 56  Mexico        WC-2018       3
# 57  Peru          WC-2018       3
# 58  Senegal       WC-2018       3
# 59  Australia     WC-2022       2
# 60  Canada        WC-2022       2
# 61  Ivory Coast   WC-2014       2
# 62  Russia        WC-2018       2
# 63  Senegal       WC-2022       2
# 64  Uruguay       WC-2010       2
# 65  Wales         WC-2022       2
# 66  Brazil        WC-2010       1
# 67  Cameroon      WC-2014       1
# 68  Denmark       WC-2010       1
# 69  Denmark       WC-2018       1
# 70  Denmark       WC-2022       1
# 71  France        WC-2010       1
# 72  Germany       WC-2010       1
# 73  Japan         WC-2018       1
# 74  Mexico        WC-2022       1
# 75  Netherlands   WC-2010       1
# 76  Russia        WC-2014       1
# 77  Slovenia      WC-2010       1
# 78  Uruguay       WC-2014       1
# 79  Uruguay       WC-2018       1

# %% [markdown]
# Looking at this table we can see two clear trends. Firstl;y, some countries have almost all their players missing, there's a big chance that some of this countries leagues are simply not in our dataste and hence most of their national team players arent available. The other trend is that the oldest the tournamnet the most missing players. Since there is a good chance many of this players we just dont have data for I've decided to take all temas with 8 or more missing players out of our training data.

# %%
fullworldcup_players %>% 
  filter(full_name %in% nonmatched) %>%
    group_by(team_name, tournament_id) %>%
        summarize(players = n(), .groups = "drop") %>%
            filter(players >= 8) %>%
                summarize(total_players = sum(players))

563-265
# Out:
#   total_players
# 1 265
# [1] 298

# %% [markdown]
# Now we only have 298 missing players, this is reasonable at around 10% of total players. It's inevitable to work with some incomplete data and assuming most of the missing plkayers are lower profile players we can assume that there effect on team performances would be lower so the model shouldn't be affected too strongly.

# %%
matched_players <- worldcup_players %>%
  rename(player_id_fj = player_id) %>%
  distinct(full_name, .keep_all = TRUE) %>%
  inner_join(
    player_names %>%
      rename(
        player_id_kag = player_id,
        full_name = name
      ) %>%
      distinct(full_name, .keep_all = TRUE),
    by = "full_name"
  ) %>%
  select(full_name, player_id_fj, player_id_kag)

# %%
str(matched_players)
head(matched_players)
dim(matched_players)
any(duplicated(matched_players$player_id_fj))
any(duplicated(matched_players$player_id_kag))
# Out:
# tibble [1,811 x 3] (S3: tbl_df/tbl/data.frame)
#  $ full_name    : chr [1:1811] "Anthar Yahia" "Rafik Halliche" "Ryad Boudebouz" "Mehdi Lacen" ...
#  $ player_id_fj : chr [1:1811] "P-77742" "P-19453" "P-70903" "P-23484" ...
#  $ player_id_kag: int [1:1811] 5586 67815 77826 35539 76406 20903 19385 74768 8060 12351 ...
#   full_name          player_id_fj player_id_kag
# 1 Anthar Yahia       P-77742       5586
# 2 Rafik Halliche     P-19453      67815
# 3 Ryad Boudebouz     P-70903      77826
# 4 Mehdi Lacen        P-23484      35539
# 5 Abdelkader Ghezzal P-22008      76406
# 6 Rafik Djebbour     P-10693      20903
# [1] 1811    3
# [1] FALSE
# [1] FALSE

# %%
saveRDS(matched_players, here("1.DataCleaning-R", "Data", "RDS", "Matching.rds"))
